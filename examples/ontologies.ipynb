# %%
import rdflib

# %%
filename = r"C:\Users\matth\AppData\Local\opencefadb\opencefadb\database\metadata\ssno_13351343.ttl"

# %%
g = rdflib.Graph()
base_uri = "http://example.org/"

# %%
g.parse(source=filename, publicID=base_uri)
# Out:
# C:\Users\matth\AppData\Local\opencefadb\opencefadb\database\metadata\ssno_13351343.ttl does not look like a valid URI, trying to serialize this will break.
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 g.parse(source=filename, publicID=base_uri)
#
# File ~\anaconda3\envs\opencefadb\lib\site-packages\rdflib\graph.py:1467, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1372 def parse(
#    1373     self,
#    1374     source: Optional[
#    (...)
#    1382     **args: Any,
#    1383 ) -> Graph:
#    1384     """
#    1385     Parse an RDF source adding the resulting triples to the Graph.
#    1386
#    (...)
#    1464
#    1465     """
# -> 1467     source = create_input_source(
#    1468         source=source,
#    1469         publicID=publicID,
#    1470         location=location,
#    1471         file=file,
# ...

# %%
with open("ssno.jsonld", "w", encoding="utf-8") as f:
    f.write(g.serialize(format="json-ld", context={"ssno": "https://matthiasprobst.github.io/ssno#"}))

# %%
rdflib.Graph().parse(source="me.ttl", format="ttl").serialize(format="json-ld")
# Out:
# '[\n  {\n    "@id": "http://purl.org/dc/terms/title",\n    "@type": [\n      "http://www.w3.org/2002/07/owl#AnnotationProperty"\n    ],\n    "http://www.w3.org/2000/01/rdf-schema#domain": [\n      {\n        "@id": "https://matthiasprobst.github.io/ssno#StandardNameTable"\n      }\n    ],\n    "http://www.w3.org/2000/01/rdf-schema#range": [\n      {\n        "@id": "http://www.w3.org/2001/XMLSchema#anyURI"\n      }\n    ]\n  },\n  {\n    "@id": "http://purl.org/dc/terms/creator",\n    "@type": [\n      "http://www.w3.org/2002/07/owl#AnnotationProperty"\n    ]\n  },\n  {\n    "@id": "http://w3id.org/nfdi4ing/metadata4ing#TextVariable",\n    "@type": [\n      "http://www.w3.org/2002/07/owl#Class"\n    ],\n    "http://www.w3.org/2000/01/rdf-schema#isDefinedBy": [\n      {\n        "@id": "http://w3id.org/nfdi4ing/metadata4ing#"\n      }\n    ],\n    "http://www.w3.org/2000/01/rdf-schema#subClassOf": [\n      {\n        "@id": "http://www.molmod.info/semantics/pims-ii.ttl#Variable"\n    
# ...
